# %% [markdown]
# ## 1. Why Should We Write Functions?

# %%
from IPython.display import Image
Image(filename='Images/Why_we_write_functions.png')

# %% [markdown]
# ## 2. Passing Arguments and Returning a Value

# %%
Image(filename='Images/Passing Arguments and Returning a Value.png')

# %% [markdown]
# ## 3. What is a parameter in a function?

# %%
Image(filename='Images/What is parameter?.png')

# %% [markdown]
# ### Short explanation on ARGUMENTS and PARAMETERS:
#
# ### ________       From a function's perspective:
#
# ####        A parameter is the variable listed inside the parentheses in the function definition.
#
# ####        An argument is the value that are sent to the function when it is called.
#
# #####                        source: https://www.w3schools.com/python/python_functions.asp

# %% [markdown]
# #### Example

# %%
def my_function(name):   #   name is a parameter
  print(name + " likes Python programming.")

# we call the function with an argument
my_function("Emil")          # Emil is an argument
# Out:
# Emil likes Python programming.

# %% [markdown]
# ## 4. Parameters or Arguments?
#
# #### The terms parameter and argument can be used for the same thing: information that is passed into a function.
#
# ### So don't worry if you mix those two deffinitions.

# %%
# This function expects 2 arguments, and gets 2 arguments:

def my_function(fname, lname):
  print(fname + " " + lname)


# This function gets 2 arguments:
my_function("Emil", "Svensson")
# Out:
# Emil Svensson

# %% [markdown]
# ## 5. Arbitrary Arguments, *args
#
# #### If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
#
# #### This way the function will receive a tuple of arguments, and can access the items accordingly:

# %%
# If the number of arguments is unknown, add a * before the parameter name:

def my_function(*kids):
  print("The youngest child is " + kids[-1])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %% [markdown]
# ##### Arbitrary Arguments are often shortened to *args in Python documentations.

# %%
# If the number of arguments is unknown, add a * before the parameter name:

def my_function(*args):
  print("The youngest child is " + args[-1])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %% [markdown]
# ## 6. Keyword Arguments
#
# #### You can also send arguments with the key = value syntax.
#
# #### This way the order of the arguments does not matter.

# %%
def my_function(child3, child2, child1):
  print("The youngest child is " + child3)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")
# Out:
# The youngest child is Linus

# %% [markdown]
# ## 7. Arbitrary Keyword Arguments, **kwargs
#
# #### If you do not know how many keyword arguments that will be passed into your function, add two asterisk: ** before the parameter name in the function definition.
#
# #### This way the function will receive a dictionary of arguments, and can access the items accordingly:

# %%
def my_function(**kid):
  print("His last name is " + kid["lname"])

my_function(fname = "Emil", lname = "Svensson")
# Out:
# His last name is Svensson

# %% [markdown]
# ##### Arbitrary Arguments are often shortened to **kwargs in Python documentations.

# %%
def my_function(**kwargs):
  print("His last name is " + kwargs["lname"])

my_function(fname = "Emil", lname = "Svensson")
# Out:
# His last name is Svensson

# %% [markdown]
# ## 8. Default Parameter Value
#
# #### The following example shows how to use a default parameter value.
#
# #### If we call the function without argument, it uses the default value:

# %%
def my_function(country = "Norway"):
  print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %% [markdown]
# ## 9. Passing a List as an Argument
#
# #### You can send any data types of argument to a function (string, number, list, dictionary etc.), and it will be treated as the same data type inside the function.
#
# #### E.g. if you send a List as an argument, it will still be a List when it reaches the function:

# %%
def my_function(food):
    for x in food:
        print(x)

fruits = ["apple", "banana", "cherry"]

my_function(fruits)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## 10. Return Values
#
# #### To let a function return a value, use the return statement:

# %%
def my_function(x):
    return 5 * x

print(my_function(3))
print(my_function(5))
print(my_function(9))
# Out:
# 15
# 25
# 45

# %%
## 11. The pass Statement

function definitions cannot be empty, but if you for some reason have a function definition with no content, put in the pass statement to avoid getting an error.
